# %%
import spacy
import pandas as pd
import time
import json

# %%
movie_names = []
with open('..//data//imsdb_sample.txt') as fp:
    for line in fp:
        movie_names.append(line.replace("\n",""))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-abf73a72094e> in <module>
#       1 movie_names = []
# ----> 2 with open('..//..//data//imsdb_sample.txt') as fp:
#       3     for line in fp:
#       4         movie_names.append(line.replace("\n",""))
#
# FileNotFoundError: [Errno 2] No such file or directory: '..//..//data//imsdb_sample.txt'

# %%
movie_names[0:10]
# Out:
# ['10 Things I Hate About You',
#  '12',
#  '12 and Holding',
#  '12 Monkeys',
#  '12 Years a Slave',
#  '127 Hours',
#  '1492: Conquest of Paradise',
#  '15 Minutes',
#  '17 Again',
#  '187']

# %%
# Reading word lists
corpus1 = []
with open('data//bad_words.txt') as fp:
    for line in fp:
        corpus1.append(line.replace("\n",""))
        
with open('data//words.txt') as fp:
    text = fp.readlines()
    corpus2 = [x.strip().lower() for x in text[0].split(",")]


bad_words_corpus = set(corpus1 + corpus2)
print(len(bad_words_corpus))
# Out:
# 2267

# %% [markdown]
# ## Creating the SpaCy pipeline
# #### Batch size set to 100 based on tests

# %%
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1050000

# %%
error_list = [] # helpful in avoiding file not found errors
def get_features(index,name):
    features = {}
    completed_list = [] # storing all words
    count = 0
    name_path = name
    name_path = name_path.replace(":","_")
    name_path = name_path.replace("?","_")
    path = path = "data//movie_scripts//Script_" + name_path + ".txt"
    
    try:
        with open(path) as fp:
            script=fp.readlines()
        pos = ['ADJ','NOUN','VERB']
        for doc in nlp.pipe(script, disable=["parser","lemmatizer","ner"], batch_size=100):
            for token in doc:
                token_type = token.pos_
                if token_type in pos:
                    completed_list.append(token.text.lower())
                    if token.text in bad_words_corpus:
                        count +=1
        features['index'] = index
        features['movie_name'] = name
        features['count'] = count
        features['words'] = completed_list
        
    except OSError:
        error_list.append(name)
    
    return features

# %%
# data = []

# start = time.time()

# for movie_index, name in enumerate(movie_names):
#     data.append(get_features(movie_index,name))    
#     if movie_index%100 == 0:
#         print("Processed: ",movie_index)
# end = time.time()
# print(end-start)

# %% [markdown]
# ### Total runtime: ~26 minutes

# %% [markdown]
# #### Saving data to avoid re-running nlp pipeline

# %%
# with open('data//output_dataframe.txt', 'w') as fout:
#     json.dump(data , fout)

# %%
with open('data//output_dataframe.txt', 'r') as fin:
    data = json.load(fin)

# %%
len(data)
# Out:
# 1093

# %%
movie_data = pd.DataFrame(data)

# %%
movie_data.head(20)
# Out:
#     index                  movie_name  count  \
# 0     0.0  10 Things I Hate About You  348.0
# 1     1.0                          12  170.0
# 2     2.0              12 and Holding  352.0
# 3     3.0                  12 Monkeys  541.0
# 4     4.0            12 Years a Slave  645.0
# 5     5.0                   127 Hours  366.0
# 6     6.0  1492: Conquest of Paradise  390.0
# 7     7.0                  15 Minutes  737.0
# 8     8.0                    17 Again  255.0
# 9     9.0                         187  492.0
# 10   10.0       2001: A Space Odyssey  275.0
# 11   11.0                        2012  426.0
# 12   12.0                   25th Hour  385.0
# 13   13.0          30 Minutes or Less  792.0
# 14   14.0                          42  381.0
# 15   15.0               44 Inch Chest  401.0
# 16   16.0                     48 Hrs.  633.0
# 17   17.0                       50-50  402.0
# 18   18.0          500 Days of Summer  221.0
# 19   19.0                         8MM  629.0
#
#                                                 words
# 0   [things, hate, written, based, taming, padua, ...
# 1   [cut, red, convertible, driving, car, passes, ...
# 2   [holding, written, 04.06.04, morning, twin, bo...
# 3   [original, screenplay, inspired, fade, face, y...
# 4   [years, slave, written, close, black, hands, o...
# 5   [written, massive, crowd, sports, stadium, far...
# 6   [conquest, fade, credits, music, start, man, e...
# 7   [words, panning, words, side, plane, tray, tab...
# 8   [written, senior, high, school, dusk, few, car...
# 9   [draft, purposes, pair, black, penny, loafers,...
# 10  [screenplay, title, years, african, drylands, ...
# 11  [written, 19th, listen, immortal, music, infin...
# 12  [25th, hour, entertainment, blac, dog, sleeps,...
# 13  [minutes, less, written, following, based, shi...
# 14  [written, double, double, fills, screen, falli...
# 15  [inch, chest, written, prologue, stagnant, bla...
# 16  [green, hills, bisected, ribbon, highway, road...
# 17  [i'm, written, fade, picture, perfect, day, be...
# 18  [days, summer, written, simple, roll, girl, sa...
# 19  [millimeter, written, first, weary, tourist, f...

# %%
movie_data = movie_data.dropna()

# %%
# movie_data['percent_profanity'] = movie_data.apply(lambda x: get_percentage(x), axis=1)
movie_data['percent_profanity'] = (movie_data['count'] / movie_data['words'].str.len()) * 100

# %%
movie_data
# Out:
#        index                  movie_name  count  \
# 0        0.0  10 Things I Hate About You  348.0
# 1        1.0                          12  170.0
# 2        2.0              12 and Holding  352.0
# 3        3.0                  12 Monkeys  541.0
# 4        4.0            12 Years a Slave  645.0
# ...      ...                         ...    ...
# 1088  1088.0         You Can Count On Me  230.0
# 1089  1089.0             You've Got Mail  237.0
# 1090  1090.0             Youth in Revolt  492.0
# 1091  1091.0            Zero Dark Thirty  444.0
# 1092  1092.0                  Zerophilia  223.0
#
#                                                   words  percent_profanity
# 0     [things, hate, written, based, taming, padua, ...           5.392005
# 1     [cut, red, convertible, driving, car, passes, ...           3.451777
# 2     [holding, written, 04.06.04, morning, twin, bo...           5.365036
# 3     [original, screenplay, inspired, fade, face, y...           4.435517
# 4     [years, slave, written, close, black, hands, o...           6.136429
# ...                                                 ...                ...
# 1088  [count, shooting, draft, car, moving, shifting...           3.973739
# 1089  [got, based, corner, 2nd, revised, sense, cybe...           2.885669
# 1090  [youth, written, comes, sound, deep, breaths, ...           5.413732
# 1091  [written, hear, actual, recorded, emergency, c...           6.016260
# 1092  [written, revised, dark, trees, dripping, vine...           4.615066
#
# [1092 rows x 5 columns]

# %%
# Fixing movie titles format for easier merge. Titles originally of the form (Abyss, The). Converting to (The Abyss)

# %%
connectors = ('The','A','An')
def fix_titles(row):
    item = row[1]
    if item.endswith(connectors):
        item_replace = item.split(' ')
        item_replace.insert(0,item_replace[-1])
        item_replace.pop(-1)
        item_replace = ' '.join(item_replace)[:-1]

        item_replace = item_replace.replace('_',":")

        return item_replace
    else:
        return item

# %%
movie_data['movie_name'] = movie_data['movie_name'].astype('str')
movie_data['movie_name'] = movie_data.apply(lambda x: fix_titles(x),axis=1)

# %% [markdown]
# ### Reading IMDb data

# %%
df_1 =  pd.read_csv('IMDBdata_MainData.csv')
df_2 = pd.read_csv('IMDBdata_MainData2.csv')

# %%
imdb_data = pd.concat([df_1,df_2]).drop_duplicates(subset=['Title']).reset_index(drop=True)

# %%
imdb_data.head()
# Out:
#                           Title  Year      Rated     Released  Runtime  \
# 0             Code Name: K.O.Z.  2015  NOT RATED  13 Feb 2015  114 min
# 1              Saving Christmas  2014         PG  14 Nov 2014   80 min
# 2  Superbabies: Baby Geniuses 2  2004         PG  27 Aug 2004   88 min
# 3           Daniel der Zauberer  2004  NOT RATED  12 Aug 2004   81 min
# 4      Manos: The Hands of Fate  1966  NOT RATED  15 Nov 1966   70 min
#
#                     Genre          Director  \
# 0          Crime, Mystery       Celal Çimen
# 1          Comedy, Family      Darren Doane
# 2  Comedy, Family, Sci-Fi         Bob Clark
# 3  Comedy, Crime, Fantasy       Ulli Lommel
# 4                  Horror  Harold P. Warren
#
#                                              Writer  \
# 0                                               NaN
# 1                      Darren Doane, Cheston Hervey
# 2  Steven Paul (story), Gregory Poppen (screenplay)
# 3                          Ulli Lommel (screenplay)
# 4                     Harold P. Warren (screenplay)
#
#                                               Actors  \
# 0  Cem Kurtoglu, Hakan Ural, Hazim Körmükçü, Tolg...
# 1  Kirk Cameron, Darren Doane, Bridgette Cameron,...
# 2  Jon Voight, Scott Baio, Vanessa Angel, Skyler ...
# 3  Daniel Küblböck, Ulli Lommel, Rudolf Waldemar ...
# 4  Tom Neyman, John Reynolds, Diane Adelson, Haro...
#
#                                                 Plot  ... imdbRating  \
# 0  A look at the 17-25 December 2013 corruption s...  ...        1.6
# 1  Kirk is enjoying the annual Christmas party ex...  ...        1.6
# 2  A group of smart-talking toddlers find themsel...  ...        2.0
# 3  Evil assassins want to kill Daniel Kublbock, t...  ...        1.9
# 4  A family gets lost on the road and stumbles up...  ...        1.9
#
#   imdbVotes     imdbID   Type          DVD   BoxOffice  \
# 0    24,600  tt4458206  movie          NaN         NaN
# 1    12,686  tt4009460  movie  03 Nov 2015  $2,778,297
# 2    26,376  tt0270846  movie  04 Jan 2005  $9,016,422
# 3    13,060  tt0421051  movie          NaN         NaN
# 4    31,768  tt0060666  movie  07 Oct 2003         NaN
#
#                  Production  \
# 0                       NaN
# 1  IPD/Samuel Goldwyn Films
# 2                      Sony
# 3                       NaN
# 4           Sinister Cinema
#
#                                              Website Response  \
# 0                                                NaN     True
# 1                    http://www.savingchristmas.com/     True
# 2  http://www.sonypictures.com/movies/superbabies...     True
# 3                                                NaN     True
# 4                                                NaN     True
#
#                                            tomatoURL
# 0                                                NaN
# 1  http://www.rottentomatoes.com/m/kirk_camerons_...
# 2  http://www.rottentomatoes.com/m/super_babies_b...
# 3  http://www.rottentomatoes.com/m/daniel_der_zau...
# 4  http://www.rottentomatoes.com/m/manos-the-hand...
#
# [5 rows x 27 columns]

# %%
merged = movie_data.merge(imdb_data, left_on='movie_name',right_on='Title',how='inner')

# %%
merged.shape
# 715 rows.
# Out:
# (715, 32)

# %%
def fix_year(year):
    if '–' in str(year):
        year = year.split("–")[0]
    return year
merged.Year = merged['Year'].apply(lambda x: fix_year(x))

# %%
merged.Year = merged.Year.astype('int32')

# %%
# Making values uniiform

merged['Rated']= merged['Rated'].replace('TV-14', 'PG-13')
merged['Rated']= merged['Rated'].replace('TV-MA', 'R')
merged['Rated']= merged['Rated'].replace('TV-PG', 'PG')
merged['Rated']= merged['Rated'].replace('NC-17', 'R')
merged['Rated']= merged['Rated'].replace('TV-G', 'G')
merged['Rated']= merged['Rated'].replace('TV-Y', 'G')

#removing values which are not rated
merged = merged[merged.Rated != 'UNRATED']
merged = merged[merged.Rated != 'APPROVED']
merged = merged[merged.Rated != 'NOT RATED']

# %%
merged['Rated'].value_counts()
# Out:
# R         399
# PG-13     225
# PG         62
# G          11
# PASSED      1
# Name: Rated, dtype: int64

# %% [markdown]
# ## Vizualization

# %%
merged_PG13 = merged[merged['Rated'] == 'PG-13']
merged_PG13.head()
# Out:
#     index                  movie_name  count  \
# 0     0.0  10 Things I Hate About You  348.0
# 1     3.0                  12 Monkeys  541.0
# 5     8.0                    17 Again  255.0
# 7    11.0                        2012  426.0
# 10   14.0                          42  381.0
#
#                                                 words  percent_profanity  \
# 0   [things, hate, written, based, taming, padua, ...           5.392005
# 1   [original, screenplay, inspired, fade, face, y...           4.435517
# 5   [written, senior, high, school, dusk, few, car...           3.960857
# 7   [written, 19th, listen, immortal, music, infin...           4.777391
# 10  [written, double, double, fills, screen, falli...           4.368264
#
#                          Title  Year  Rated     Released  Runtime  ...  \
# 0   10 Things I Hate About You  1999  PG-13  31 Mar 1999   97 min  ...
# 1                   12 Monkeys  2015  PG-13  16 Jan 2015   42 min  ...
# 5                     17 Again  2009  PG-13  17 Apr 2009  102 min  ...
# 7                         2012  2009  PG-13  13 Nov 2009  158 min  ...
# 10                          42  2013  PG-13  12 Apr 2013  128 min  ...
#
#    imdbRating imdbVotes     imdbID    Type          DVD     BoxOffice  \
# 0         7.2   239,625  tt0147800   movie  12 Oct 1999           NaN
# 1         7.6    26,117  tt3148266  series          NaN           NaN
# 5         6.4   153,226  tt0974661   movie  11 Aug 2009   $64,087,443
# 7         5.8   298,869  tt1190080   movie  02 Mar 2010  $166,112,167
# 10        7.5    69,898  tt0453562   movie  16 Jul 2013   $95,001,343
#
#                 Production                             Website Response  \
# 0     Buena Vista Pictures                                 NaN     True
# 1                      NaN                                 NaN     True
# 5          New Line Cinema        http://www.17againmovie.com/     True
# 7   Sony Pictures/Columbia  http://www.whowillsurvive2012.com/     True
# 10   Warner Bros. Pictures      http://42movie.warnerbros.com/     True
#
#                                             tomatoURL
# 0   http://www.rottentomatoes.com/m/10_things_i_ha...
# 1                                                 NaN
# 5   http://www.rottentomatoes.com/m/1201402-17_again/
# 7               http://www.rottentomatoes.com/m/2012/
# 10           http://www.rottentomatoes.com/m/42_2013/
#
# [5 rows x 32 columns]

# %%
count_over_years = merged.groupby('Year')['percent_profanity'].mean().reset_index()
count_over_years.sort_values(by='Year',inplace=True)

# count_over_years

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(11.7,8.27)})
# sns.regplot(x=count_over_years['Year'],y=count_over_years['percent_profanity'],ci=95,)

fig = sns.regplot(x=count_over_years['Year'],y=count_over_years['percent_profanity'],ci=95,)
plt.xlabel("Year")
plt.ylabel("% Explicit content")
plt.title("Explicit content over Years")
# Out:
# Text(0.5, 1.0, 'Explicit content over Years')

# %%
from scipy.stats import pearsonr
pearsonr(count_over_years['Year'],count_over_years['percent_profanity'])
# Out:
# (0.41841965918892476, 0.001477634407887239)

# %% [markdown]
# ### Shows a mild positive correlation, with a p-value of 0.0014. Statistically significant

# %%
merged['Year'].max()
# Out:
# 2017
